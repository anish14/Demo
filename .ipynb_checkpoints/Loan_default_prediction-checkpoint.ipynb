# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import time
import warnings
warnings.filterwarnings('ignore')

# %%
pip install imbalanced-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 1. ID = Customer ID of Applicant
# 2. year = Year of Application
# 3. loan limit = maximum avaliable amount of the loan allowed to be taken
# 4. Gender = sex type
# 5. approv_in_adv = Is loan pre-approved or not
# 6. loan_type = Type of loan
# 7. loan_purpose = the reason you want to borrow money
# 8. Credit_Worthiness = is how a lender determines that you will default on your debt obligations, or how worthy you are to receive new credit.
# 9. open_credit = is a pre-approved loan between a lender and a borrower. It allows the borrower to make repeated withdrawals up to a certain limit.
# 10. business_or_commercial = Usage type of the loan amount
# 11. loan_amount = The exact loan amount
# 12. rate_of_interest = is the amount a lender charges a borrower and is a percentage of the principal—the amount loaned.
# 13. Interest_rate_spread = the difference between the interest rate a financial institution pays to depositors and the interest rate it receives from loans
# 14. Upfront_charges = Fee paid to a lender by a borrower as consideration for making a new loan
# 15. term = the loan's repayment period
# 16. Neg_ammortization = refers to a situation when a loan borrower makes a payment less than the standard installment set by the bank.
# 17. interest_only = amount of interest only without principles
# 18. lump_sum_payment = is an amount of money that is paid in one single payment rather than in installments.
# 19. property_value = the present worth of future benefits arising from the ownership of the property
# 20. construction_type = Collateral construction type
# 21. occupancy_type = classifications refer to categorizing structures based on their usage
# 22. Secured_by = Type of Collatoral
# 23. total_units = number of unites
# 24. income = refers to the amount of money, property, and other transfers of value received over a set period of time
# 25. credit_type = type of credit
# 26. co-applicant_credit_type = is an additional person involved in the loan application process. Both applicant and co-applicant apply and sign for the loan
# 27. age = applicant's age
# 28. submission_of_application = Ensure the application is complete or not
# 29. LTV = life-time value (LTV) is a prognostication of the net profit
# 30. Region = applicant's place
# 31. Security_Type = Type of Collatoral
# 32. status = Loan status (1 - Loan Defaulted/ 0 - Didn't Default)
# 33. dtir1 = debt-to-income ratio

# %%
df = pd.read_csv('Loan_Default.csv')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df.head(10)
# Out:
#       ID  year loan_limit             Gender approv_in_adv loan_type  \
# 0  24890  2019         cf  Sex Not Available         nopre     type1
# 1  24891  2019         cf               Male         nopre     type2
# 2  24892  2019         cf               Male           pre     type1
# 3  24893  2019         cf               Male         nopre     type1
# 4  24894  2019         cf              Joint           pre     type1
# 5  24895  2019         cf              Joint           pre     type1
# 6  24896  2019         cf              Joint           pre     type1
# 7  24897  2019        NaN             Female         nopre     type1
# 8  24898  2019         cf              Joint         nopre     type1
# 9  24899  2019         cf  Sex Not Available         nopre     type3
#
#   loan_purpose Credit_Worthiness open_credit business_or_commercial  \
# 0           p1                l1        nopc                  nob/c
# 1           p1                l1        nopc                    b/c
# ...

# %%
df.shape
# Out:
# (148670, 34)

# %%
df['Status'].value_counts(normalize=True)*100 # very unbalanced, 25% defaulted
# Out:
# 0    75.355485
# 1    24.644515
# Name: Status, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148670 entries, 0 to 148669
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   ID                         148670 non-null  int64
#  1   year                       148670 non-null  int64
#  2   loan_limit                 145326 non-null  object
#  3   Gender                     148670 non-null  object
#  4   approv_in_adv              147762 non-null  object
#  5   loan_type                  148670 non-null  object
#  6   loan_purpose               148536 non-null  object
#  7   Credit_Worthiness          148670 non-null  object
#  8   open_credit                148670 non-null  object
#  9   business_or_commercial     148670 non-null  object
#  10  loan_amount                148670 non-null  int64
#  11  rate_of_interest           112231 non-null  float64
#  12  Interest_rate_spread       112031 non-null  float64
# ...

# %%
# missing values
df.isnull().sum()/len(df)*100
# Out:
# ID                            0.000000
# year                          0.000000
# loan_limit                    2.249277
# Gender                        0.000000
# approv_in_adv                 0.610749
# loan_type                     0.000000
# loan_purpose                  0.090133
# Credit_Worthiness             0.000000
# open_credit                   0.000000
# business_or_commercial        0.000000
# loan_amount                   0.000000
# rate_of_interest             24.509989
# Interest_rate_spread         24.644515
# Upfront_charges              26.664425
# term                          0.027578
# Neg_ammortization             0.081388
# interest_only                 0.000000
# lump_sum_payment              0.000000
# property_value               10.155378
# construction_type             0.000000
# occupancy_type                0.000000
# Secured_by                    0.000000
# total_units                   0.000000
# income                        6.154571
# ...

# %%
# converting all column names to lower case
df.columns = df.columns.str.lower()

# %%
#df.info()

# %%
# feature assessment:

#df['year'].value_counts() # drop, only 1 value
#df['loan_limit'].value_counts() # drop, values dont make sense
#df['gender'].value_counts() # drop, missing values plus gender won't be a deciding factor
#df['approv_in_adv'].value_counts() # n encoding needed
#df['loan_type'].value_counts() # n encoding needed
#df['loan_purpose'].value_counts() # drop, vague values
#df['credit_worthiness'].value_counts(normalize=True)*100 # drop, 1 value dominates 96%
#df['open_credit'].value_counts(normalize=True)*100 # drop
#df['business_or_commercial'].value_counts() # drop, vague values
#df['loan_amount'].value_counts() # no changes required
#df['rate_of_interest'].value_counts() # fill missing values
#df['interest_rate_spread'].value_counts() # fill missing values
#df['upfront_charges'].value_counts() # fill missing values
#df['term'].value_counts()
#df['neg_ammortization'].value_counts(normalize=True)*100 # n encoding needed
#df['interest_only'].value_counts() # drop, vague
#df['lump_sum_payment'].value_counts(normalize=True)*100 # drop
#df['property_value'].value_counts()
#df['construction_type'].value_counts() # drop
#df['occupancy_type'].value_counts(normalize=True)*100 # drop, vague
#df['secured_by'].value_counts() # drop
#df['total_units'].value_counts() # drop, vague
#df['income'].value_counts()
#df['credit_type'].value_counts() # n encoding needed
#df['credit_score'].value_counts()
#df['co-applicant_credit_type'].value_counts() # n encoding needed
#df['age'].value_counts() # o encoding needed
#df['submission_of_application'].value_counts() # drop, doesn't make sense
#df['ltv'].value_counts()
#df['region'].value_counts() # n encoding needed
#df['security_type'].value_counts() # drop
#df['status'].value_counts() 
#df['dtir1'].value_counts()

# %%
# dropping columns

cols = ['id', 'year', 'gender', 'loan_limit','loan_purpose','credit_worthiness', 'open_credit','business_or_commercial','interest_only', 'lump_sum_payment','construction_type', 'occupancy_type', 'secured_by', 'total_units','submission_of_application','security_type']

df.drop(cols, axis=1, inplace=True)
df['status'] = df['status'].astype('category')

# %%
df.shape
# Out:
# (148670, 18)

# %%
df.head()
# Out:
#   approv_in_adv loan_type  loan_amount  rate_of_interest  \
# 0         nopre     type1       116500               NaN
# 1         nopre     type2       206500               NaN
# 2           pre     type1       406500              4.56
# 3         nopre     type1       456500              4.25
# 4           pre     type1       696500              4.00
#
#    interest_rate_spread  upfront_charges   term neg_ammortization  \
# 0                   NaN              NaN  360.0           not_neg
# 1                   NaN              NaN  360.0           not_neg
# 2                0.2000            595.0  360.0           neg_amm
# 3                0.6810              NaN  360.0           not_neg
# 4                0.3042              0.0  360.0           not_neg
#
#    property_value   income credit_type  credit_score co-applicant_credit_type  \
# 0        118000.0   1740.0         EXP           758                      CIB
# ...

# %%
# check for duplicate rows
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148670 entries, 0 to 148669
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   approv_in_adv             147762 non-null  object
#  1   loan_type                 148670 non-null  object
#  2   loan_amount               148670 non-null  int64
#  3   rate_of_interest          112231 non-null  float64
#  4   interest_rate_spread      112031 non-null  float64
#  5   upfront_charges           109028 non-null  float64
#  6   term                      148629 non-null  float64
#  7   neg_ammortization         148549 non-null  object
#  8   property_value            133572 non-null  float64
#  9   income                    139520 non-null  float64
#  10  credit_type               148670 non-null  object
#  11  credit_score              148670 non-null  int64
#  12  co-applicant_credit_type  148670 non-null  object
# ...

# %%
df.describe()
# Out:
#         loan_amount  rate_of_interest  interest_rate_spread  upfront_charges  \
# count  1.486700e+05     112231.000000         112031.000000    109028.000000
# mean   3.311177e+05          4.045476              0.441656      3224.996127
# std    1.839093e+05          0.561391              0.513043      3251.121510
# min    1.650000e+04          0.000000             -3.638000         0.000000
# 25%    1.965000e+05          3.625000              0.076000       581.490000
# 50%    2.965000e+05          3.990000              0.390400      2596.450000
# 75%    4.365000e+05          4.375000              0.775400      4812.500000
# max    3.576500e+06          8.000000              3.357000     60000.000000
#
#                 term  property_value         income   credit_score  \
# count  148629.000000    1.335720e+05  139520.000000  148670.000000
# mean      335.136582    4.978935e+05    6957.338876     699.789103
# std        58.409084    3.599353e+05    6496.586382     115.875857
# ...

# %%
# one red flag i see is min rate_of_interest is zero which shouldn't be the case, deleting rows where it is zero.

index_names = df[ df['rate_of_interest'] == 0 ].index
print(index_names)

df.drop(index_names, inplace=True)
# Out:
# Int64Index([36272], dtype='int64')

# %%
df.describe()
# Out:
#         loan_amount  rate_of_interest  interest_rate_spread  upfront_charges  \
# count  1.486690e+05     112230.000000         112030.000000    109028.000000
# mean   3.311172e+05          4.045512              0.441692      3224.996127
# std    1.839098e+05          0.561264              0.512900      3251.121510
# min    1.650000e+04          2.125000             -1.084100         0.000000
# 25%    1.965000e+05          3.625000              0.076000       581.490000
# 50%    2.965000e+05          3.990000              0.390400      2596.450000
# 75%    4.365000e+05          4.375000              0.775400      4812.500000
# max    3.576500e+06          8.000000              3.357000     60000.000000
#
#                 term  property_value         income   credit_score  \
# count  148628.000000    1.335710e+05  139519.000000  148669.000000
# mean      335.136657    4.978924e+05    6957.388743     699.789997
# std        58.409273    3.599365e+05    6496.582962     115.875735
# ...

# %%
# lets analyze params where 'income' is zero

plt.subplots(figsize = (10, 6))
# loan amount
sns.distplot(df['loan_amount'], hist=False)
sns.distplot(df['loan_amount'][df['income']==0], hist=False)
# Out:
# <AxesSubplot:xlabel='loan_amount', ylabel='Density'>

# %%
plt.subplots(figsize = (10, 6))
# rate_of_interest
sns.distplot(df['rate_of_interest'], hist=False)
sns.distplot(df['rate_of_interest'][df['income']==0], hist=False)
# Out:
# <AxesSubplot:xlabel='rate_of_interest', ylabel='Density'>

# %%
plt.subplots(figsize = (10, 6))
# upfront_charges
sns.distplot(df['upfront_charges'], hist=False)
sns.distplot(df['upfront_charges'][df['income']==0], hist=False)
# Out:
# <AxesSubplot:xlabel='upfront_charges', ylabel='Density'>

# %%
plt.subplots(figsize = (10, 6))
# term
sns.distplot(df['term'], hist=False)
sns.distplot(df['term'][df['income']==0], hist=False)
# Out:
# <AxesSubplot:xlabel='term', ylabel='Density'>

# %%
plt.subplots(figsize = (10, 6))
# property_value
sns.distplot(df['property_value'], hist=False)
sns.distplot(df['property_value'][df['income']==0], hist=False)
# Out:
# <AxesSubplot:xlabel='property_value', ylabel='Density'>

# %%
plt.subplots(figsize = (10, 6))
# credit_score
sns.distplot(df['credit_score'], hist=False)
sns.distplot(df['credit_score'][df['income']==0], hist=False)
# Out:
# <AxesSubplot:xlabel='credit_score', ylabel='Density'>

# %%
plt.subplots(figsize = (10, 6))
# ltv
sns.distplot(df['ltv'], hist=False)
sns.distplot(df['ltv'][df['income']==0], hist=False)
# Out:
# <AxesSubplot:xlabel='ltv', ylabel='Density'>

# %%
plt.subplots(figsize = (10, 6))
# dtir1
sns.kdeplot(data=df, x=df['dtir1'], color='r')
sns.kdeplot(data=df, x=df['dtir1'][df['income']==0], color='g')
# Out:
# <AxesSubplot:xlabel='dtir1', ylabel='Density'>

# %%
plt.subplots(figsize = (16, 8))
sns.scatterplot(df['income'],df['loan_amount'])
# Out:
# <AxesSubplot:xlabel='income', ylabel='loan_amount'>

# %%
plt.subplots(figsize = (16, 8))
sns.scatterplot(df['rate_of_interest'],df['loan_amount'], hue=df['term'])
# Out:
# <AxesSubplot:xlabel='rate_of_interest', ylabel='loan_amount'>

# %%
plt.subplots(figsize = (16, 8))
sns.barplot(df['term'],df['income'])
# Out:
# <AxesSubplot:xlabel='term', ylabel='income'>

# %%
plt.subplots(figsize = (16, 8))
sns.barplot(df['term'],df['loan_amount'])
# Out:
# <AxesSubplot:xlabel='term', ylabel='loan_amount'>

# %%
plt.subplots(figsize = (16, 8))
sns.scatterplot(df['credit_score'],df['loan_amount'])
# Out:
# <AxesSubplot:xlabel='credit_score', ylabel='loan_amount'>

# %%
plt.subplots(figsize = (16, 8))
sns.scatterplot(df['rate_of_interest'],df['credit_score'])
# Out:
# <AxesSubplot:xlabel='rate_of_interest', ylabel='credit_score'>

# %%
plt.subplots(figsize = (16, 8))
sns.scatterplot(df['dtir1'],df['income'])
# Out:
# <AxesSubplot:xlabel='dtir1', ylabel='income'>

# %%
plt.subplots(figsize = (16, 8))
sns.scatterplot(df['dtir1'],df['loan_amount'])
# Out:
# <AxesSubplot:xlabel='dtir1', ylabel='loan_amount'>

# %%
plt.subplots(figsize = (16, 8))
sns.scatterplot(df['property_value'],df['loan_amount'])
# Out:
# <AxesSubplot:xlabel='property_value', ylabel='loan_amount'>

# %%
l1 = ['loan_amount', 'rate_of_interest', 'interest_rate_spread', 'upfront_charges', 'term', 'property_value', 'income', 'credit_score', 'ltv', 'dtir1']

for col in l1:
    plt.subplots(figsize = (10, 6))
    sns.kdeplot(data = df, x = df[col], hue=df['status'], fill = True)

# %%
# Looks like loan_amount has a lot of outliers

# %%
sns.boxplot(df['loan_amount'])
# Out:
# <AxesSubplot:xlabel='loan_amount'>

# %%
# checking values, for status=1 rate_of_interest is mostly null
print(df['rate_of_interest'][df['status']==1].value_counts().sum())
print(df['rate_of_interest'][df['status']==1].isnull().sum())
print(df['rate_of_interest'][df['status']==0].value_counts().sum())

print(df['rate_of_interest'][df['status']==1].mean())
print(df['rate_of_interest'][df['status']==0].mean())
print(df['rate_of_interest'].mean())
# Out:
# 200
# 36439
# 112030
# 4.350500000000002
# 4.0449673748090795
# 4.045511850662575

# %%
# missing values
df.isnull().sum()/len(df)*100
# Out:
# approv_in_adv                0.610753
# loan_type                    0.000000
# loan_amount                  0.000000
# rate_of_interest            24.510153
# interest_rate_spread        24.644680
# upfront_charges             26.663931
# term                         0.027578
# neg_ammortization            0.081389
# property_value              10.155446
# income                       6.154612
# credit_type                  0.000000
# credit_score                 0.000000
# co-applicant_credit_type     0.000000
# age                          0.134527
# ltv                         10.155446
# region                       0.000000
# status                       0.000000
# dtir1                       16.224633
# dtype: float64

# %%
# checking missing values

print(df['rate_of_interest'][df['status']==1].isnull().sum())
print(df['rate_of_interest'][df['status']==0].isnull().sum())

print(df['interest_rate_spread'][df['status']==1].isnull().sum())
print(df['interest_rate_spread'][df['status']==0].isnull().sum())

print(df['upfront_charges'][df['status']==1].isnull().sum())
print(df['upfront_charges'][df['status']==0].isnull().sum())
# Out:
# 36439
# 0
# 36639
# 0
# 36486
# 3155

# %%
# 25% is already pretty high for null values plus it is biased towards one class
# Hence dropping these 3 cols for now
df.drop(['rate_of_interest','interest_rate_spread','upfront_charges'], axis=1, inplace=True)

# %%
print(df['property_value'][df['status']==1].isnull().sum())
print(df['property_value'][df['status']==0].isnull().sum())

print(df['income'][df['status']==1].isnull().sum())
print(df['income'][df['status']==0].isnull().sum())

print(df['ltv'][df['status']==1].isnull().sum())
print(df['ltv'][df['status']==0].isnull().sum())

print(df['dtir1'][df['status']==1].isnull().sum())
print(df['dtir1'][df['status']==0].isnull().sum())
# Out:
# 15096
# 2
# 1239
# 7911
# 15096
# 2
# 16310
# 7811

# %%
sns.distplot(df['property_value'][df['status']==1], hist=False)
sns.distplot(df['property_value'][df['status']==0], hist=False)
# Out:
# <AxesSubplot:xlabel='property_value', ylabel='Density'>

# %%
# replacing with median values from the same class

df['property_value'].fillna(df['property_value'][df['status']==1].median(), inplace = True)

# %%
sns.distplot(df['income'][df['status']==1], hist=False)
sns.distplot(df['income'][df['status']==0], hist=False)
# Out:
# <AxesSubplot:xlabel='income', ylabel='Density'>

# %%
df['income'].fillna(df['income'].median(), inplace = True)

# %%
sns.distplot(df['ltv'][df['status']==1], hist=False)
sns.distplot(df['ltv'][df['status']==0], hist=False)
# Out:
# <AxesSubplot:xlabel='ltv', ylabel='Density'>

# %%
# replacing with median values from the same class

df['ltv'].fillna(df['ltv'][df['status']==1].median(), inplace = True)

# %%
sns.distplot(df['dtir1'][df['status']==1], hist=False)
sns.distplot(df['dtir1'][df['status']==0], hist=False)
# Out:
# <AxesSubplot:xlabel='dtir1', ylabel='Density'>

# %%
df['dtir1'].fillna(df['dtir1'].median(), inplace = True)

# %%
# missing values
df.isnull().sum()/len(df)*100
# Out:
# approv_in_adv               0.610753
# loan_type                   0.000000
# loan_amount                 0.000000
# term                        0.027578
# neg_ammortization           0.081389
# property_value              0.000000
# income                      0.000000
# credit_type                 0.000000
# credit_score                0.000000
# co-applicant_credit_type    0.000000
# age                         0.134527
# ltv                         0.000000
# region                      0.000000
# status                      0.000000
# dtir1                       0.000000
# dtype: float64

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='most_frequent')
df[['approv_in_adv','term','neg_ammortization','age']] = imputer.fit_transform(df[['approv_in_adv','term','neg_ammortization','age']])

# %%
# missing values
df.isnull().sum()/len(df)*100
# Out:
# approv_in_adv               0.0
# loan_type                   0.0
# loan_amount                 0.0
# term                        0.0
# neg_ammortization           0.0
# property_value              0.0
# income                      0.0
# credit_type                 0.0
# credit_score                0.0
# co-applicant_credit_type    0.0
# age                         0.0
# ltv                         0.0
# region                      0.0
# status                      0.0
# dtir1                       0.0
# dtype: float64

# %%
# Collinearity

plt.figure(figsize=(15,12))
sns.heatmap(df.corr(), annot = True)
plt.show()

# %%
# acceptable levels of correlation between cols, moving to encoding of categorical variables

# first encoding ordinal variables

from sklearn import preprocessing
label_enc = preprocessing.LabelEncoder()

df['term'] = label_enc.fit_transform(df['term'])
df['age'] = label_enc.fit_transform(df['age'])

# %%
# encoding nominal variables

enc_df = pd.get_dummies(df[['approv_in_adv','loan_type','neg_ammortization','credit_type','co-applicant_credit_type','region']], drop_first=True)
enc_df.head()
# Out:
#    approv_in_adv_pre  loan_type_type2  loan_type_type3  \
# 0                  0                0                0
# 1                  0                1                0
# 2                  1                0                0
# 3                  0                0                0
# 4                  1                0                0
#
#    neg_ammortization_not_neg  credit_type_CRIF  credit_type_EQUI  \
# 0                          1                 0                 0
# 1                          1                 0                 1
# 2                          0                 0                 0
# 3                          1                 0                 0
# 4                          1                 1                 0
#
#    credit_type_EXP  co-applicant_credit_type_EXP  region_North-East  \
# 0                1                             0                  0
# 1                0                             1                  0
# ...

# %%
enc_df.shape
# Out:
# (148669, 11)

# %%
# dropping originals and concat with enc_df
df.drop(['approv_in_adv','loan_type','neg_ammortization','credit_type','co-applicant_credit_type','region'], axis=1, inplace=True)

df = pd.concat([df,enc_df], axis=1)
print(df.shape)
df.head()
# Out:
# (148669, 20)
#    loan_amount  term  property_value   income  credit_score  age        ltv  \
# 0       116500    25        118000.0   1740.0           758    0  98.728814
# 1       206500    25        348000.0   4980.0           552    3  79.362416
# 2       406500    25        508000.0   9480.0           834    1  80.019685
# 3       456500    25        658000.0  11880.0           587    2  69.376900
# 4       696500    25        758000.0  10440.0           602    0  91.886544
#
#   status  dtir1  approv_in_adv_pre  loan_type_type2  loan_type_type3  \
# 0      1   45.0                  0                0                0
# 1      1   39.0                  0                1                0
# 2      0   46.0                  1                0                0
# 3      0   42.0                  0                0                0
# 4      0   39.0                  1                0                0
#
#    neg_ammortization_not_neg  credit_type_CRIF  credit_type_EQUI  \
# ...

# %%
x = df.drop('status', axis=1)
y = df['status']
print(x.shape)
print(y.shape)
# Out:
# (148669, 19)
# (148669,)

# %%
# train_test_split

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df.drop('status', axis=1), df['status'], test_size=0.3, random_state=56)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
x_train.head()
# Out:
# (104068, 19)
# (44601, 19)
# (104068,)
# (44601,)
#         loan_amount  term  property_value  income  credit_score  age  \
# 14091        346500    25        608000.0  7200.0           716    4
# 26515        456500    25        558000.0  8940.0           753    2
# 134509       496500    25        648000.0  8280.0           512    3
# 21343        366500    25        778000.0  9000.0           532    3
# 70366        616500    25        658000.0  9300.0           883    1
#
#               ltv  dtir1  approv_in_adv_pre  loan_type_type2  loan_type_type3  \
# 14091   56.990132   37.0                  0                0                0
# 26515   81.810036   36.0                  0                0                0
# 134509  76.620370   37.0                  0                0                0
# 21343   47.107969   44.0                  0                0                0
# 70366   93.693009   33.0                  0                1                0
#
# ...

# %%
y_train.value_counts()
# Out:
# 0    78436
# 1    25632
# Name: status, dtype: int64

# %%
#from imblearn.over_sampling import SMOTE
#sm = SMOTE()
#x_train, y_train = sm.fit_resample(x_train, y_train)

# %%
#y_train.value_counts()

# %%
# base model
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

lr = LogisticRegression(random_state=56)
lr2 = LogisticRegression(class_weight='balanced', random_state=56)
dt = DecisionTreeClassifier(random_state=56)
knn = KNeighborsClassifier()
rf = RandomForestClassifier(random_state=56)
rf2 = RandomForestClassifier(class_weight='balanced', random_state=56)

models = [lr,lr2,dt,knn,rf,rf2]

for m in models:
    m.fit(x_train, y_train)
    print(m, ':', m.score(x_train, y_train).round(4), m.score(x_test, y_test).round(4))
# Out:
# LogisticRegression(random_state=56) : 0.7559 0.7557
# LogisticRegression(class_weight='balanced', random_state=56) : 0.5164 0.5141
# DecisionTreeClassifier(random_state=56) : 1.0 0.8046
# KNeighborsClassifier() : 0.8652 0.8336
# RandomForestClassifier(random_state=56) : 0.9999 0.8821
# RandomForestClassifier(class_weight='balanced', random_state=56) : 1.0 0.8812

# %%
# dt and random forest are overfitting, knn is giving the best accuracy
# cross-validation

for m in models:
    scores = cross_val_score(m, x, y, cv=5, scoring='f1')
    print(m)
    print(scores)
    print('Mean=', scores.mean())
    print('Std=', scores.std())
    print()
# Out:
# LogisticRegression(random_state=56)
# [0.0199946  0.01972706 0.01785231 0.01597401 0.01651326]
# Mean= 0.018012249159628367
# Std= 0.0016307819100255321
#
# LogisticRegression(class_weight='balanced', random_state=56)
# [0.41264546 0.40629106 0.40832483 0.41107204 0.41310963]
# Mean= 0.4102886047870172
# Std= 0.002606278549226554
#
# DecisionTreeClassifier(random_state=56)
# [0.6216342  0.61518134 0.60874172 0.61175847 0.61802064]
# Mean= 0.6150672760785305
# Std= 0.004534769313343468
#
# KNeighborsClassifier()
# [0.58539478 0.58782697 0.5801217  0.58635015 0.59340289]
# Mean= 0.586619299717434
# Std= 0.004272382657964293
#
# RandomForestClassifier(random_state=56)
# [0.7068907  0.70308668 0.70160881 0.70306303 0.70502869]
# Mean= 0.7039355811815471
# Std= 0.0018343096035021537
#
# RandomForestClassifier(class_weight='balanced', random_state=56)
# [0.69999141 0.69848601 0.69541457 0.69938546 0.70008525]
# Mean= 0.6986725401622145
# Std= 0.0017258389386210352

# %%
# random forest has the highest f1 score 
from sklearn.metrics import classification_report

model2 = [dt,knn,rf]

for m in model2:
    print(m)
    m.fit(x_train, y_train)
    y_test_pred = m.predict(x_test)
    print('Test Classification report:')
    print(classification_report(y_test,y_test_pred))
    y_train_pred = m.predict(x_train)
    print('Train Classification report:')
    print(classification_report(y_train, y_train_pred))
    print()
# Out:
# DecisionTreeClassifier(random_state=56)
# Test Classification report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.86      0.87     33594
#            1       0.60      0.63      0.61     11007
#
#     accuracy                           0.80     44601
#    macro avg       0.74      0.75      0.74     44601
# weighted avg       0.81      0.80      0.81     44601
#
# Train Classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     78436
#            1       1.00      1.00      1.00     25632
#
#     accuracy                           1.00    104068
#    macro avg       1.00      1.00      1.00    104068
# weighted avg       1.00      1.00      1.00    104068
#
#
# KNeighborsClassifier()
# Test Classification report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.95      0.90     33594
# ...

# %%
# hyper tuning for randomf to avoid overfitting
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

m1 = RandomForestClassifier(random_state=56, n_jobs=-1)

params = [{'n_estimators': range(30,101,5), 'max_depth': range(10,31)}]

gs = GridSearchCV(estimator=m1, param_grid=params, scoring='f1', cv=5, verbose=1, n_jobs=-1)

#rs = RandomizedSearchCV(estimator=m1, param_grid=params, scoring='f1', cv=5, verbose=1, n_jobs=-1)

begin = time.time()
gs.fit(x_train,y_train)
end = time.time()
print(f"Total runtime of the program is {end - begin}")
# Out:
# Fitting 5 folds for each of 315 candidates, totalling 1575 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [83], in <cell line: 14>()
#      11 #rs = RandomizedSearchCV(estimator=m1, param_grid=params, scoring='f1', cv=5, verbose=1, n_jobs=-1)
#      13 begin = time.time()
# ---> 14 gs.fit(x_train,y_train)
#      15 end = time.time()
#      16 print(f"Total runtime of the program is {end - begin}")
#
# File ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:875, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     869     results = self._format_results(
#     870         all_candidate_params, n_splits, all_out, all_more_results
#     871     )
#     873     return results
# --> 875 self._run_search(evaluate_candidates)
#     877 # multimetric is determined here because in the case of a callable
# ...

# %%
gs.best_params_
# Out:
# {'max_depth': 10, 'max_features': 6, 'max_samples': 0.6, 'n_estimators': 50}

# %%
# # Standard scaler
# from sklearn.preprocessing import StandardScaler
# from sklearn.preprocessing import MinMaxScaler

# scaler = StandardScaler()
# scaler2 = MinMaxScaler()

# scaler2.fit(x_train)

# x_train_scaled = scaler2.transform(x_train)
# x_test_scaled = scaler2.transform(x_test)

# x_train_scaled = pd.DataFrame(x_train_scaled, columns=x_train.columns)
# x_test_scaled = pd.DataFrame(x_test_scaled, columns=x_test.columns)

# x_train_scaled.head()

# %%
# # training
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.metrics import accuracy_score
# from sklearn.metrics import classification_report
# from sklearn.metrics import confusion_matrix

# model1 = RandomForestClassifier(random_state=56)

# from sklearn.model_selection import GridSearchCV

# #params = [{'n_estimators':[15,25,35,50,65], 'max_depth': range(5,21), 'max_features': range(6,11), 'min_samples_leaf': [1,1.5,2,2.5]}]

# #gs = GridSearchCV(estimator=model1, param_grid=params, scoring='accuracy', cv=5)

# #gs.fit(x_train_scaled,y_train)

# #gs.best_params_
# 'min_samples_split': range(2,21), 'max_leaf_nodes': range(10,51,10),
# , 'max_features': range(3,11), 'max_samples': [0.2,0.4,0.6,0.8]

# %%
# plt.figure(figsize=(10, 7))
# sns.barplot(y=x_train_scaled.columns, x=model1.feature_importances_, )
# plt.title("Feature Importance")
# plt.show()
